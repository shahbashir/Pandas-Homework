# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %%
whale_returns=pd.read_csv("whale_returns.csv",index_col='Date',parse_dates=True,infer_datetime_format=True)
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
whale_returns.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
whale_returns.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
whale_returns.columns
# Out:
# Index(['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC'],
#       dtype='object')

# %%
algo_returns=pd.read_csv("algo_returns.csv",index_col='Date',parse_dates=True,infer_datetime_format=True)
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
algo_returns.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %%
algo_returns.dropna()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
sp500_history=pd.read_csv("sp500_history.csv",index_col='Date',parse_dates=True,infer_datetime_format=True)
sp500_history
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06
# ...              ...
# 2012-10-05  $1460.93
# 2012-10-04  $1461.40
# 2012-10-03  $1450.99
# 2012-10-02  $1445.75
# 2012-10-01  $1444.49
#
# [1649 rows x 1 columns]

# %%
sp500_history.isnull()
# Out:
#             Close
# Date
# 2019-04-23  False
# 2019-04-22  False
# 2019-04-18  False
# 2019-04-17  False
# 2019-04-16  False
# ...           ...
# 2012-10-05  False
# 2012-10-04  False
# 2012-10-03  False
# 2012-10-02  False
# 2012-10-01  False
#
# [1649 rows x 1 columns]

# %%
sp500_history.dropna
# Out:
# <bound method DataFrame.dropna of                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06
# ...              ...
# 2012-10-05  $1460.93
# 2012-10-04  $1461.40
# 2012-10-03  $1450.99
# 2012-10-02  $1445.75
# 2012-10-01  $1444.49
#
# [1649 rows x 1 columns]>

# %%
sp500_history.Daily_return=[x.strip('$')for x in sp500_history.Daily_return]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-1832934e48d5> in <module>
# ----> 1 sp500_history.Daily_return=[x.strip('$')for x in sp500_history.Daily_return]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Daily_return'

# %%
sp500_history

# %%
sp500_history["Daily_return"] = sp500_history["Daily_return"].astype(float).pct_change()

# %%
sp500_history

# %%
combined_df= pd.concat([whale_returns,algo_returns,sp500_history], axis="columns" , join="inner")

# %%
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# ...

# %%
combined_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
correlation=combined_df.pct_change().corr()
correlation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
whale_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
algo_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp500_history.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
correlation.head()
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.002890
# PAULSON & CO.INC.                             0.002890            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.022263            0.035632
# BERKSHIRE HATHAWAY INC                        0.000339            0.002151
# Algo 1                                        0.000038            0.006392
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.022263
# PAULSON & CO.INC.                               0.035632
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                         -0.014014
# Algo 1                                          0.003318
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.000339  0.000038 -0.005757
# ...

# %%
whale_returns.std().sum()
# Out:
# 0.03847388682423699

# %%
algo_returns.std().sum()
# Out:
# 0.0164388567039475

# %%
sp500_history.std().sum()
# Out:
# 0.008134642617809523

# %%
whale_returns.rolling(window=252).std()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# ...                               ...                 ...
# 2019-04-25                   0.009327            0.007337
# 2019-04-26                   0.009340            0.007358
# 2019-04-29                   0.009330            0.007355
# 2019-04-30                   0.009095            0.007356
# 2019-05-01                   0.009100            0.007318
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                          NaN                     NaN
# ...

# %%
algo_returns.rolling(window=252).std()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28       NaN       NaN
# 2014-05-29       NaN       NaN
# 2014-05-30       NaN       NaN
# 2014-06-02       NaN       NaN
# 2014-06-03       NaN       NaN
# ...              ...       ...
# 2019-04-25  0.008215  0.008600
# 2019-04-26  0.008216  0.008606
# 2019-04-29  0.008215  0.008600
# 2019-04-30  0.008217  0.008601
# 2019-05-01  0.008214  0.008596
#
# [1241 rows x 2 columns]

# %%
sp500_history.rolling(window=252).std()
# Out:
#             Daily_return
# Date
# 2019-04-23           NaN
# 2019-04-22           NaN
# 2019-04-18           NaN
# 2019-04-17           NaN
# 2019-04-16           NaN
# ...                  ...
# 2012-10-05      0.007429
# 2012-10-04      0.007430
# 2012-10-03      0.007396
# 2012-10-02      0.007376
# 2012-10-01      0.007365
#
# [1649 rows x 1 columns]

# %%
whale_returns.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
algo_returns.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp500_history.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
correlation.plot()
# Out:
# <AxesSubplot:>

# %%
whale_returns.cov()
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     0.000061            0.000038
# PAULSON & CO.INC.                             0.000038            0.000049
# TIGER GLOBAL MANAGEMENT LLC                   0.000048            0.000033
# BERKSHIRE HATHAWAY INC                        0.000076            0.000049
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.000048
# PAULSON & CO.INC.                               0.000033
# TIGER GLOBAL MANAGEMENT LLC                     0.000117
# BERKSHIRE HATHAWAY INC                          0.000059
#
#                              BERKSHIRE HATHAWAY INC
# SOROS FUND MANAGEMENT LLC                  0.000076
# PAULSON & CO.INC.                          0.000049
# TIGER GLOBAL MANAGEMENT LLC                0.000059
# BERKSHIRE HATHAWAY INC                     0.000165

# %%
sp500_history.cov()
# Out:
#               Daily_return
# Daily_return      0.000066

# %%
combined_df1= pd.concat([algo_returns, sp500_history], axis= "columns", join= "inner")
combined_df1
# Out:
#               Algo 1    Algo 2  Daily_return
# Date
# 2014-05-28  0.001745       NaN     -0.005338
# 2014-05-29  0.003978       NaN     -0.001840
# 2014-05-30  0.004464       NaN     -0.000727
# 2014-06-02  0.005692       NaN      0.000379
# 2014-06-03  0.005292       NaN     -0.001888
# ...              ...       ...           ...
# 2019-04-16 -0.006945  0.002899      0.002279
# 2019-04-17 -0.010301 -0.005228     -0.001577
# 2019-04-18 -0.000588 -0.001229     -0.001011
# 2019-04-22  0.000677 -0.001936     -0.008764
# 2019-04-23  0.004969  0.009622           NaN
#
# [1235 rows x 3 columns]

# %%
combined_df1.sort_index(inplace=True)

# %%
combined_df1.head()
# Out:
#                algo1  algo2     sp500
# Date
# 2014-05-28  0.001745    NaN -0.005338
# 2014-05-29  0.003978    NaN -0.001840
# 2014-05-30  0.004464    NaN -0.000727
# 2014-06-02  0.005692    NaN  0.000379
# 2014-06-03  0.005292    NaN -0.001888

# %%
coveriance= combined_df1["algo1"].cov(combined_df1["sp500"])
coveriance1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-93ba22c3254a> in <module>
# ----> 1 coveriance= combined_df1["algo1"].cov(combined_df1["sp500"])
#       2 coveriance1
#
# NameError: name 'combined_df1' is not defined

# %%
variance= combined_df1["sp500"].var()
variance
# Out:
# 7.090074853523431e-05

# %%
algo_returns_beta= coveriance1/variance
algo_returns_beta
# Out:
# -0.0455279721551232

# %%
rolling_covariance = combined_df1["algo1"].rolling(window=30).cov(combined_df1["sp500"])
rolling_covariance.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
rolling_covariance2 = combined_df1["algo2"].rolling(window=30).cov(combined_df1["sp500"])
rolling_covariance2.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
combined_rolling_covariance= rolling_covariance+rolling_covariance2
combined_rolling_covariance.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
anual_return_whale= whale_returns.pct_change(252)
anual_return_whale.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
anual_return_algo= algo_returns.pct_change(252)
anual_return_algo.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
anual_return_sp500= sp500_history.pct_change(252)
anual_return_sp500.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %%
aapl=pd.read_csv("aapl_historical.csv", index_col="Trade DATE", parse_dates=True,infer_datetime_format=True)
goog=pd.read_csv("goog_historical.csv", index_col="Trade DATE", parse_dates=True,infer_datetime_format=True)
cost=pd.read_csv("cost_historical.csv", index_col="Trade DATE", parse_dates=True,infer_datetime_format=True)

# %%
aapl
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75
# ...           ...     ...
# 2018-05-17   AAPL  186.99
# 2018-05-16   AAPL  188.18
# 2018-05-15   AAPL  186.44
# 2018-05-14   AAPL  188.15
# 2018-05-11   AAPL  188.59
#
# [250 rows x 2 columns]

# %%
goog
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40
# ...           ...      ...
# 2018-05-17   GOOG  1078.59
# 2018-05-16   GOOG  1081.77
# 2018-05-15   GOOG  1079.23
# 2018-05-14   GOOG  1100.20
# 2018-05-11   GOOG  1098.26
#
# [250 rows x 2 columns]

# %%
cost
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62
# ...           ...     ...
# 2018-05-17   COST  199.60
# 2018-05-16   COST  198.71
# 2018-05-15   COST  195.48
# 2018-05-14   COST  195.88
# 2018-05-11   COST  195.76
#
# [250 rows x 2 columns]

# %%
combined_stocks= pd.concat([aapl,goog,cost], axis="columns" , join="inner")
combined_stocks
# Out:
#            Symbol    NOCP Symbol     NOCP Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72   GOOG  1162.38   COST  243.47
# 2019-05-08   AAPL  202.90   GOOG  1166.27   COST  241.34
# 2019-05-07   AAPL  202.86   GOOG  1174.10   COST  240.18
# 2019-05-06   AAPL  208.48   GOOG  1189.39   COST  244.23
# 2019-05-03   AAPL  211.75   GOOG  1185.40   COST  244.62
# ...           ...     ...    ...      ...    ...     ...
# 2018-05-17   AAPL  186.99   GOOG  1078.59   COST  199.60
# 2018-05-16   AAPL  188.18   GOOG  1081.77   COST  198.71
# 2018-05-15   AAPL  186.44   GOOG  1079.23   COST  195.48
# 2018-05-14   AAPL  188.15   GOOG  1100.20   COST  195.88
# 2018-05-11   AAPL  188.59   GOOG  1098.26   COST  195.76
#
# [250 rows x 6 columns]

# %%
aapl.isnull()
# Out:
#             Symbol   NOCP
# Trade DATE
# 2019-05-09   False  False
# 2019-05-08   False  False
# 2019-05-07   False  False
# 2019-05-06   False  False
# 2019-05-03   False  False
# ...            ...    ...
# 2018-05-17   False  False
# 2018-05-16   False  False
# 2018-05-15   False  False
# 2018-05-14   False  False
# 2018-05-11   False  False
#
# [250 rows x 2 columns]

# %%
aapl.dropna()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75
# ...           ...     ...
# 2018-05-17   AAPL  186.99
# 2018-05-16   AAPL  188.18
# 2018-05-15   AAPL  186.44
# 2018-05-14   AAPL  188.15
# 2018-05-11   AAPL  188.59
#
# [250 rows x 2 columns]

# %%
Daily_return =combined_stocks["NOCP"].pct_change()
Daily_return
# Out:
#                   NOCP      NOCP      NOCP
# Trade DATE
# 2019-05-09         NaN       NaN       NaN
# 2019-05-08         NaN       NaN       NaN
# 2019-05-07         NaN       NaN       NaN
# 2019-05-06  138.004565 -0.066011  9.005140
# 2019-05-03   -0.996935 -2.338267 -0.799190
# ...                ...       ...       ...
# 2018-05-17   -0.600471 -0.168808 -0.019465
# 2018-05-16   -1.489620 -0.616370  0.209463
# 2018-05-15   -4.298574  1.417979 -2.108669
# 2018-05-14   -0.187941  4.163308 -1.425590
# 2018-05-11   -0.625977 -0.882403  0.154103
#
# [250 rows x 3 columns]

# %%
Daily_return.isnull()
# Out:
#              NOCP   NOCP   NOCP
# Trade DATE
# 2019-05-09   True   True   True
# 2019-05-08   True   True   True
# 2019-05-07   True   True   True
# 2019-05-06  False  False  False
# 2019-05-03  False  False  False
# ...           ...    ...    ...
# 2018-05-17  False  False  False
# 2018-05-16  False  False  False
# 2018-05-15  False  False  False
# 2018-05-14  False  False  False
# 2018-05-11  False  False  False
#
# [250 rows x 3 columns]

# %%
Daily_return.dropna()
# Out:
#                   NOCP      NOCP      NOCP
# Trade DATE
# 2019-05-06  138.004565 -0.066011  9.005140
# 2019-05-03   -0.996935 -2.338267 -0.799190
# 2019-05-02    3.109467 -4.761931  5.562272
# 2019-05-01   -0.139865 -1.263099 -0.928374
# 2019-04-30    4.310162 -3.178774  9.805919
# ...                ...       ...       ...
# 2018-05-17   -0.600471 -0.168808 -0.019465
# 2018-05-16   -1.489620 -0.616370  0.209463
# 2018-05-15   -4.298574  1.417979 -2.108669
# 2018-05-14   -0.187941  4.163308 -1.425590
# 2018-05-11   -0.625977 -0.882403  0.154103
#
# [247 rows x 3 columns]
